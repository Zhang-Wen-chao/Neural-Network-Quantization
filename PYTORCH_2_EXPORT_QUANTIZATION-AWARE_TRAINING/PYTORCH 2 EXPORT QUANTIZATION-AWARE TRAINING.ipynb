# %%
import os
import sys
import time
import numpy as np

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision.models.resnet import resnet18
import torchvision.transforms as transforms

# Set up warnings
import warnings
warnings.filterwarnings(
    action='ignore',
    category=DeprecationWarning,
    module=r'.*'
)
warnings.filterwarnings(
    action='default',
    module=r'torch.ao.quantization'
)

# Specify random seed for repeatable results
_ = torch.manual_seed(191009)

class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)

def accuracy(output, target, topk=(1,)):
    """
    Computes the accuracy over the k top predictions for the specified
    values of k.
    """
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

def evaluate(model, criterion, data_loader, device):
    torch.ao.quantization.move_exported_model_to_eval(model)
    top1 = AverageMeter('Acc@1', ':6.2f')
    top5 = AverageMeter('Acc@5', ':6.2f')
    cnt = 0
    with torch.no_grad():
        for image, target in data_loader:
            image = image.to(device)
            target = target.to(device)
            output = model(image)
            loss = criterion(output, target)
            cnt += 1
            acc1, acc5 = accuracy(output, target, topk=(1, 5))
            top1.update(acc1[0], image.size(0))
            top5.update(acc5[0], image.size(0))
    print('')

    return top1, top5

def load_model(model_file):
    model = resnet18(pretrained=False)
    state_dict = torch.load(model_file)
    model.load_state_dict(state_dict)
    return model

def print_size_of_model(model):
    if isinstance(model, torch.jit.RecursiveScriptModule):
        torch.jit.save(model, "temp.p")
    else:
        torch.jit.save(torch.jit.script(model), "temp.p")
    print("Size (MB):", os.path.getsize("temp.p")/1e6)
    os.remove("temp.p")

def prepare_data_loaders(data_path):
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
    dataset = torchvision.datasets.ImageNet(
        data_path, split="train", transform=transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ]))
    dataset_test = torchvision.datasets.ImageNet(
        data_path, split="val", transform=transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            normalize,
        ]))

    train_sampler = torch.utils.data.RandomSampler(dataset)
    test_sampler = torch.utils.data.SequentialSampler(dataset_test)

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=train_batch_size,
        sampler=train_sampler)

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=eval_batch_size,
        sampler=test_sampler)

    return data_loader, data_loader_test

def train_one_epoch(model, criterion, optimizer, data_loader, device, ntrain_batches):
    # Note: do not call model.train() here, since this doesn't work on an exported model.
    # Instead, call `torch.ao.quantization.move_exported_model_to_train(model)`, which will
    # be added in the near future
    top1 = AverageMeter('Acc@1', ':6.2f')
    top5 = AverageMeter('Acc@5', ':6.2f')
    avgloss = AverageMeter('Loss', '1.5f')

    cnt = 0
    for image, target in data_loader:
        start_time = time.time()
        print('.', end = '')
        cnt += 1
        image, target = image.to(device), target.to(device)
        output = model(image)
        loss = criterion(output, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        acc1, acc5 = accuracy(output, target, topk=(1, 5))
        top1.update(acc1[0], image.size(0))
        top5.update(acc5[0], image.size(0))
        avgloss.update(loss, image.size(0))
        if cnt >= ntrain_batches:
            print('Loss', avgloss.avg)

            print('Training: * Acc@1 {top1.avg:.3f} Acc@5 {top5.avg:.3f}'
                  .format(top1=top1, top5=top5))
            return

    print('Full imagenet train set:  * Acc@1 {top1.global_avg:.3f} Acc@5 {top5.global_avg:.3f}'
          .format(top1=top1, top5=top5))
    return

data_path = '../FX_GRAPH_MODE_POST_TRAINING_STATIC_QUANTIZATION/data/imagenet'
saved_model_dir = './data/'
float_model_file = 'resnet18_pretrained_float.pth'

train_batch_size = 32
eval_batch_size = 32

data_loader, data_loader_test = prepare_data_loaders(data_path)
example_inputs = (next(iter(data_loader))[0])
criterion = nn.CrossEntropyLoss()
float_model = load_model(saved_model_dir + float_model_file).to("cuda")
# Out:
# /home/student001/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/student001/anaconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# %env TORCH_LOGS=+dynamo
# %env TORCHDYNAMO_VERBOSE=1

from torch._export import capture_pre_autograd_graph

example_inputs = (torch.rand(2, 3, 224, 224),)
exported_model = capture_pre_autograd_graph(float_model, example_inputs)
# Out:
# env: TORCH_LOGS=+dynamo
# env: TORCHDYNAMO_VERBOSE=1
# ---------------------------------------------------------------------------
# TorchRuntimeError                         Traceback (most recent call last)
# /tmp/ipykernel_1288918/3341480643.py in <module>
#       5
#       6 example_inputs = (torch.rand(2, 3, 224, 224),)
# ----> 7 exported_model = capture_pre_autograd_graph(float_model, example_inputs)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_export/__init__.py in capture_pre_autograd_graph(f, args, kwargs, constraints)
#     143
#     144     with torch._dynamo.config.patch(dataclasses.asdict(DEFAULT_EXPORT_DYNAMO_CONFIG)):  # type: ignore[attr-defined]
# --> 145         m = torch._dynamo.export(
#     146             f,
#     147             constraints=constraints,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py in inner(*args, **kwargs)
#    1138             # TODO(voz): We may have instances of `f` that mutate inputs, we should track sideffects and reject.
#    1139             try:
# -> 1140                 result_traced = opt_f(*args, **kwargs)
#    1141             except ConstraintViolationError as e:
#    1142                 constraint_violation_error = e
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py in _fn(*args, **kwargs)
#     326             dynamic_ctx.__enter__()
#     327             try:
# --> 328                 return fn(*args, **kwargs)
#     329             finally:
#     330                 set_eval_frame(prior)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/eval_frame.py in catch_errors(frame, cache_entry, frame_state)
#     488
#     489         with compile_lock, _disable_current_modes():
# --> 490             return callback(frame, cache_entry, hooks, frame_state)
#     491
#     492     catch_errors._torchdynamo_orig_callable = callback  # type: ignore[attr-defined]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in _fn(*args, **kwargs)
#     131         cleanup = setup_compile_debug()
#     132         try:
# --> 133             return fn(*args, **kwargs)
#     134         finally:
#     135             cleanup.close()
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in _convert_frame_assert(frame, cache_entry, hooks, frame_state)
#     387         )
#     388
# --> 389         return _compile(
#     390             frame.f_code,
#     391             frame.f_globals,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, export_constraints, hooks, cache_size, frame, frame_state, compile_id)
#     567     with compile_context(CompileContext(compile_id)):
#     568         try:
# --> 569             guarded_code = compile_inner(code, one_graph, hooks, transform)
#     570             return guarded_code
#     571         except (
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in time_wrapper(*args, **kwargs)
#     187             with torch.profiler.record_function(f"{key} (dynamo_timed)"):
#     188                 t0 = time.time()
# --> 189                 r = func(*args, **kwargs)
#     190                 time_spent = time.time() - t0
#     191             compilation_time_metrics[key].append(time_spent)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in compile_inner(code, one_graph, hooks, transform)
#     489         for attempt in itertools.count():
#     490             try:
# --> 491                 out_code = transform_code_object(code, transform)
#     492                 orig_code_map[out_code] = code
#     493                 break
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/bytecode_transformation.py in transform_code_object(code, transformations, safe)
#    1026     propagate_line_nums(instructions)
#    1027
# -> 1028     transformations(instructions, code_options)
#    1029     return clean_and_assemble_instructions(instructions, keys, code_options)[1]
#    1030
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in transform(instructions, code_options)
#     456         try:
#     457             with tracing(tracer.output.tracing_context):
# --> 458                 tracer.run()
#     459         except (exc.RestartAnalysis, exc.SkipFrame):
#     460             raise
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in run(self)
#    2067
#    2068     def run(self):
# -> 2069         super().run()
#    2070
#    2071     def match_nested_cell(self, name, cell):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     717                     self.instruction_pointer is not None
#     718                     and not self.output.should_exit
# --> 719                     and self.step()
#     720                 ):
#     721                     pass
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     681                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     682             )
# --> 683             getattr(self, inst.opname)(inst)
#     684
#     685             return inst.opname != "RETURN_VALUE"
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     390                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     391                 )
# --> 392                 return inner_fn(self, inst)
#     393             except Unsupported as excp:
#     394                 if self.has_backedge() and self.should_compile_partial_graph():
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION(self, inst)
#    1108         args = self.popn(inst.argval)
#    1109         fn = self.pop()
# -> 1110         self.call_function(fn, args, {})
#    1111
#    1112     @break_graph_if_unsupported(push=1)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     555         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     556             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 557         self.push(fn.call_function(self, args, kwargs))
#     558
#     559     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     305                     tx, self.fn.__name__, args, kwargs, constant=self.is_constant
#     306                 ).add_options(self)
# --> 307         return super().call_function(tx, args, kwargs)
#     308
#     309     def num_parameters(self):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#     259             )
#     260
# --> 261         return super().call_function(tx, args, kwargs)
#     262
#     263
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/functions.py in call_function(self, tx, args, kwargs)
#      88         self, tx, args: "List[VariableTracker]", kwargs: "Dict[str, VariableTracker]"
#      89     ) -> "VariableTracker":
# ---> 90         return tx.inline_user_function_return(
#      91             self, list(self.self_args()) + list(args), kwargs
#      92         )
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in inline_user_function_return(self, fn, args, kwargs)
#     591         state = self.copy_graphstate()
#     592         try:
# --> 593             result = InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
#     594             self.output.guards.update(fn.guards)
#     595             return result
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in inline_call(cls, parent, func, args, kwargs)
#    2172     def inline_call(cls, parent, func, args, kwargs):
#    2173         with patch.dict(counters, {"unimplemented": counters["inline_call"]}):
# -> 2174             return cls.inline_call_(parent, func, args, kwargs)
#    2175
#    2176     @staticmethod
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in inline_call_(parent, func, args, kwargs)
#    2279         try:
#    2280             with strict_ctx:
# -> 2281                 tracer.run()
#    2282         except exc.SkipFrame as e:
#    2283             msg = f"SKIPPED INLINING {code}: {e}"
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in run(self)
#     717                     self.instruction_pointer is not None
#     718                     and not self.output.should_exit
# --> 719                     and self.step()
#     720                 ):
#     721                     pass
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in step(self)
#     681                 self.f_code.co_filename, self.lineno, self.f_code.co_name
#     682             )
# --> 683             getattr(self, inst.opname)(inst)
#     684
#     685             return inst.opname != "RETURN_VALUE"
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in wrapper(self, inst)
#     390                     self.f_code.co_filename, self.lineno, self.f_code.co_name
#     391                 )
# --> 392                 return inner_fn(self, inst)
#     393             except Unsupported as excp:
#     394                 if self.has_backedge() and self.should_compile_partial_graph():
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in CALL_FUNCTION(self, inst)
#    1108         args = self.popn(inst.argval)
#    1109         fn = self.pop()
# -> 1110         self.call_function(fn, args, {})
#    1111
#    1112     @break_graph_if_unsupported(push=1)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/symbolic_convert.py in call_function(self, fn, args, kwargs)
#     555         if inner_fn and callable(inner_fn) and is_forbidden(inner_fn):
#     556             raise AssertionError(f"Attempt to trace forbidden callable {inner_fn}")
# --> 557         self.push(fn.call_function(self, args, kwargs))
#     558
#     559     def update_locals_and_stack(self, oldvar: VariableTracker, newvar: VariableTracker):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/nn_module.py in call_function(self, tx, args, kwargs)
#     300                 from .builder import wrap_fx_proxy
#     301
# --> 302                 return wrap_fx_proxy(
#     303                     tx=tx,
#     304                     proxy=tx.output.create_proxy(
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/builder.py in wrap_fx_proxy(tx, proxy, example_value, **options)
#    1189
#    1190 def wrap_fx_proxy(tx, proxy, example_value=None, **options):
# -> 1191     return wrap_fx_proxy_cls(
#    1192         target_cls=TensorVariable,
#    1193         tx=tx,
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/variables/builder.py in wrap_fx_proxy_cls(target_cls, tx, proxy, example_value, ignore_subclass, **options)
#    1276     with preserve_rng_state():
#    1277         if example_value is None:
# -> 1278             example_value = get_fake_value(proxy.node, tx)
#    1279
#    1280         # Handle recursive calls here
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in get_fake_value(node, tx)
#    1374         elif isinstance(cause, torch.utils._sympy.value_ranges.ValueRangeError):
#    1375             raise UserError(UserErrorType.CONSTRAIN_VIOLATION, e.args[0]) from e
# -> 1376         raise TorchRuntimeError(str(e)).with_traceback(e.__traceback__) from None
#    1377
#    1378
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in get_fake_value(node, tx)
#    1335     try:
#    1336         with tx.fake_mode, enable_python_dispatcher():
# -> 1337             return wrap_fake_exception(
#    1338                 lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1339             )
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in wrap_fake_exception(fn)
#     914 def wrap_fake_exception(fn):
#     915     try:
# --> 916         return fn()
#     917     except UnsupportedFakeTensorException as e:
#     918         from .exc import unimplemented
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in <lambda>()
#    1336         with tx.fake_mode, enable_python_dispatcher():
#    1337             return wrap_fake_exception(
# -> 1338                 lambda: run_node(tx.output, node, args, kwargs, nnmodule)
#    1339             )
#    1340     except Unsupported:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in run_node(tracer, node, args, kwargs, nnmodule)
#    1408     except Exception as e:
#    1409         fn_str = f"Failed running {op} {node.target}(*{args}, **{kwargs}):\n"
# -> 1410         raise RuntimeError(fn_str + str(e)).with_traceback(e.__traceback__) from e
#    1411
#    1412     raise AssertionError(op)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_dynamo/utils.py in run_node(tracer, node, args, kwargs, nnmodule)
#    1400         elif op == "call_module":
#    1401             assert nnmodule is not None
# -> 1402             return nnmodule(*args, **kwargs)
#    1403         elif op == "get_attr":
#    1404             return tracer.get_submodule(node.target)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     169         used for normalization (i.e. in eval mode when buffers are not None).
#     170         """
# --> 171         return F.batch_norm(
#     172             input,
#     173             # If buffers are not to be tracked, ensure that they won't be updated
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2476         _verify_batch_size(input.size())
#    2477
# -> 2478     return torch.batch_norm(
#    2479         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2480     )
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_decomp/decompositions.py in native_batch_norm_decomposition(input, weight, bias, running_mean, running_var, training, momentum, eps)
#    1582     if training:
#    1583         # HACK: batch norm consolidation should clean this up so this op doesn't take in a training arg.
# -> 1584         return aten._native_batch_norm_legit(
#    1585             input, weight, bias, running_mean, running_var, training, momentum, eps
#    1586         )
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     690         # We save the function ptr as the `op` attribute on
#     691         # OpOverloadPacket to access it here.
# --> 692         return self._op(*args, **kwargs or {})
#     693
#     694     # TODO: use this to make a __dir__
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_stats.py in wrapper(*args, **kwargs)
#      18             simple_call_counter[fn.__qualname__] = 0
#      19         simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20         return fn(*args, **kwargs)
#      21     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in __torch_dispatch__(self, func, types, args, kwargs)
#    1248         assert self not in _get_current_dispatch_mode_stack(), func
#    1249         try:
# -> 1250             return self.dispatch(func, types, args, kwargs)
#    1251         except TypeError:
#    1252             log.exception("fake tensor raised TypeError")
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in dispatch(self, func, types, args, kwargs)
#    1448             ):
#    1449                 with self:
# -> 1450                     return decomposition_table[func](*args, **kwargs)
#    1451
#    1452             with self:
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_decomp/decompositions.py in _native_batch_norm_legit(input, weight, bias, running_mean, running_var, training, momentum, eps)
#    1636     eps: float,
#    1637 ) -> Tuple[Tensor, Tensor, Tensor]:
# -> 1638     output, save_mean, save_rstd, _, _ = native_batch_norm_helper(
#    1639         input, weight, bias, running_mean, running_var, training, momentum, eps, False
#    1640     )
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_decomp/decompositions.py in native_batch_norm_helper(input, weight, bias, running_mean, running_var, training, momentum, eps, functional)
#    1473         save_rstd = torch.squeeze(rstd, reduction_dims)
#    1474         if running_mean is not None:
# -> 1475             new_running_mean = momentum * save_mean + (1 - momentum) * running_mean
#    1476             if not functional:
#    1477                 running_mean.copy_(new_running_mean)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_stats.py in wrapper(*args, **kwargs)
#      18             simple_call_counter[fn.__qualname__] = 0
#      19         simple_call_counter[fn.__qualname__] = simple_call_counter[fn.__qualname__] + 1
# ---> 20         return fn(*args, **kwargs)
#      21     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in __torch_dispatch__(self, func, types, args, kwargs)
#    1248         assert self not in _get_current_dispatch_mode_stack(), func
#    1249         try:
# -> 1250             return self.dispatch(func, types, args, kwargs)
#    1251         except TypeError:
#    1252             log.exception("fake tensor raised TypeError")
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in dispatch(self, func, types, args, kwargs)
#    1543             return maybe_run_unsafe_fallback(not_implemented_error)
#    1544
# -> 1545         return self.wrap_meta_outputs_with_default_device_logic(r, func, args, kwargs)
#    1546
#    1547     # [subclass inputs]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in wrap_meta_outputs_with_default_device_logic(self, r, func, args, kwargs)
#    1609             return tree_map(partial(wrap, device=kwargs["device"]), r)
#    1610
# -> 1611         return tree_map(partial(wrap), r)
#    1612
#    1613     def gen_wrap_fn(self, func, args, kwargs):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_pytree.py in tree_map(fn, pytree)
#     281 def tree_map(fn: Any, pytree: PyTree) -> PyTree:
#     282     flat_args, spec = tree_flatten(pytree)
# --> 283     return tree_unflatten([fn(i) for i in flat_args], spec)
#     284
#     285 Type2 = Tuple[Type[T], Type[S]]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_pytree.py in <listcomp>(.0)
#     281 def tree_map(fn: Any, pytree: PyTree) -> PyTree:
#     282     flat_args, spec = tree_flatten(pytree)
# --> 283     return tree_unflatten([fn(i) for i in flat_args], spec)
#     284
#     285 Type2 = Tuple[Type[T], Type[S]]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in wrap(e, device)
#    1626                     common_device,
#    1627                     has_scalar_only_inputs,
# -> 1628                 ) = FakeTensor._find_common_device(func, args, kwargs)
#    1629
#    1630             if self.is_our_fake(e):
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in _find_common_device(func, args, kwargs)
#    1161             )
#    1162
# -> 1163         tree_map(merge_devices, args)
#    1164         tree_map(merge_devices, kwargs)
#    1165
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_pytree.py in tree_map(fn, pytree)
#     281 def tree_map(fn: Any, pytree: PyTree) -> PyTree:
#     282     flat_args, spec = tree_flatten(pytree)
# --> 283     return tree_unflatten([fn(i) for i in flat_args], spec)
#     284
#     285 Type2 = Tuple[Type[T], Type[S]]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/utils/_pytree.py in <listcomp>(.0)
#     281 def tree_map(fn: Any, pytree: PyTree) -> PyTree:
#     282     flat_args, spec = tree_flatten(pytree)
# --> 283     return tree_unflatten([fn(i) for i in flat_args], spec)
#     284
#     285 Type2 = Tuple[Type[T], Type[S]]
#
# ~/anaconda3/lib/python3.9/site-packages/torch/_subclasses/fake_tensor.py in merge_devices(t)
#    1157             # mismatching devices of non-zero dim tensors, throw
#    1158             # This might be valid behavior and need to be explicitly modeled, e.g. reshape_as
# -> 1159             raise RuntimeError(
#    1160                 f"Unhandled FakeTensor Device Propagation for {func}, found two different devices {common_device}, {t.device}"
#    1161             )
#
# TorchRuntimeError: Failed running call_module L__self___bn1(*(FakeTensor(..., size=(2, 64, 112, 112), grad_fn=<ConvolutionBackward0>),), **{}):
# Unhandled FakeTensor Device Propagation for aten.add.Tensor, found two different devices cpu, cuda:0
#
# from user code:
#    File "/home/student001/anaconda3/lib/python3.9/site-packages/torchvision/models/resnet.py", line 285, in forward
#     return self._forward_impl(x)
#   File "/home/student001/anaconda3/lib/python3.9/site-packages/torchvision/models/resnet.py", line 269, in _forward_impl
#     x = self.bn1(x)
#
# Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information

# %%
# or, to capture with dynamic dimensions:
from torch._export import dynamic_dim

example_inputs = (torch.rand(2, 3, 224, 224),)
exported_model = capture_pre_autograd_graph(
    float_model,
    example_inputs,
    constraints=[dynamic_dim(example_inputs[0], 0)],
)

# %%
from torch.ao.quantization.quantizer.xnnpack_quantizer import (
    XNNPACKQuantizer,
    get_symmetric_quantization_config,
)
quantizer = XNNPACKQuantizer()
quantizer.set_global(get_symmetric_quantization_config(is_qat=True))

# %%
prepared_model = prepare_qat_pt2e(exported_model, quantizer)
print(prepared_model)
